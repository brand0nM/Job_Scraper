# %%
# Tables are written from Scraper.py
from datetime import date
import os
import pandas as pd

non_remote = str(date.today())+".csv"
remote = "remote_"+non_remote

# %%
pd.read_csv("Listings/Dice/"+non_remote)
# Out:
#     Unnamed: 0                                          job_title  \
# 0            0                                Account Manager II
# 1            1                         Business Analyst - Remote
# 2            2                Commercial Installation Technician
# 3            3                                      Data Analyst
# 4            4                                      Data Analyst
# 5            5                              Data Quality Analyst
# 6            6   Data Scientist - Cybersecurity (BHJOB22048_730)
# 7            7                                Docucare Associate
# 8            8                                   IT Service Desk
# 9            9              Information Systems Security Officer
# 10          10                              Network Engineer III
# 11          11                               Paralegal ll-Denver
# 12          12                             Principal Engineer II
# ...

# %%
pd.read_csv("Listings/Indeed/"+non_remote)
# Out:
#     Unnamed: 0                                          job_title  \
# 0            0                        Asset Analyst and Scheduler
# 1            1                                   Business Analyst
# 2            2                              Business Data Analyst
# 3            3    Business Management Analyst - Principal Level 3
# 4            4     Business Systems Analyst III (Atlassian Tools)
# 5            5                      Data Analyst - Level I (3765)
# 6            6       Data Analyst - Must be in Lakewood/Denver CO
# 7            7              Data Analytics/Fraud Strategy Analyst
# 8            8  Data Center Facility Operations Reliability En...
# 9            9                               Data Science Analyst
# 10          10  Data Scientist with AI/ML Experience (TS/SCI w...
# 11          11                                        GIS Analyst
# 12          12                                        HCM Analyst
# ...

# %%
pd.read_csv("Listings/LinkedIn/"+non_remote)
# Out:
#     Unnamed: 0                                          job_title  \
# 0            0  Avantis/AVEVA Data Business Analyst/Project Ma...
# 1            1  Business Intelligence Analyst Intern 4 months ...
# 2            2                                       Data Analyst
# 3            3  Data Center Facility Operations Reliability En...
# 4            4                            Data Ops Infra Engineer
# 5            5                   Data Ops Infra Engineer (No C2C)
# 6            6  Data Research Analyst, gt.school (Remote) - $6...
# 7            7  Data Science / Machine Learning || San Antonio,TX
# 8            8                                     Data Scientist
# 9            9  Data Scientist, gt.school (Remote) - $60,000/y...
# 10          10                         Database Engineer (Vector)
# 11          11                                        EDI Analyst
# 12          12                    ETL Architect or Data Architect
# ...

# %%
pd.read_csv("Listings/ZipRecruiter/"+non_remote)

# %%
pd.read_csv("Listings/Monster/"+non_remote)
# Out:
#    Unnamed: 0                                    job_title  \
# 0           0                             Business Analyst
# 1           1                                 Data Analyst
# 2           2                              Mobile Engineer
# 3           3                  Principal Software Engineer
# 4           4  Reliability Engineer for CMMS / Maintenance
# 5           7                    Site Reliability Engineer
# 6           8                             Systems Engineer
# 7           9                         Systems Engineer III
#
#                        company               job_search  \
# 0  The Computer Merchant, LTD.  SQL AnalystData Analyst
# 1            Kforce Technology  SQL AnalystData Analyst
# 2                         CBRE            Data Engineer
# 3                        Jobot            Data Engineer
# 4              HNI Corporation            Data Engineer
# 5           iWorks Corporation            Data Engineer
# ...

# %% [markdown]
# ## Remote

# %%
pd.read_csv("Listings/Dice/"+remote)#.iloc[360:400]
# Out:
#      Unnamed: 0                                          job_title  \
# 360         394                                     Test Engineer
# 361         395                   Time and Attendance Coordinator
# 362         396                              UI UX Developer Lead
# 363         397                  UX Architect - REMOTE - Fulltime
# 364         398                                     UX Copywriter
# 365         399   Urgent Req : SQL Technical Architect : Remote...
# 366         401                      Usability Researcher -Remote
# 367         402                            Usability Researcher 2
# 368         403                  User Experience Researcher (HCD)
# 369         404                                VMWare Admin (NBN)
# 370         405   W2 - Cloud Architect - Operations Designer (S...
# 371         406   W2--Security Engineer-HSM Production Support ...
# 372         407   W2:::Sr Oracle DBA::REMOTE::Need local to Ind...
# ...

# %%
pd.read_csv("Listings/Indeed/"+remote)
# Out:
#     Unnamed: 0                                          job_title  \
# 0            0                        Asset Analyst and Scheduler
# 1            1                                   Business Analyst
# 2            2                              Business Data Analyst
# 3            3    Business Management Analyst - Principal Level 3
# 4            4                      Data Analyst - Level I (3765)
# 5            5       Data Analyst - Must be in Lakewood/Denver CO
# 6            6              Data Analytics/Fraud Strategy Analyst
# 7            7  Data Center Facility Operations Reliability En...
# 8            8                               Data Science Analyst
# 9            9  Data Scientist with AI/ML Experience (TS/SCI w...
# 10          10                                        GIS Analyst
# 11          11                                        HCM Analyst
# 12          12                                       Risk Analyst
# ...

# %%
pd.read_csv("Listings/LinkedIn/"+remote)
# Out:
#     Unnamed: 0                                          job_title  \
# 0            0  Business Intelligence Analyst Intern (Undergra...
# 1            1  Business Intelligence Analyst Intern 4 months ...
# 2            2                                     Data Scientist
# 3            3  Data Scientist, gt.school (Remote) - $60,000/y...
# 4            4  Data and Analytics Finance Practitioner, Gartn...
# 5            5                                  Flutter developer
# 6            6  ML/ NLP/ Gen AI/ Engineer/ Data Scientist/ Ana...
# 7            7  Oracle Customer Data Hub Business Analyst (US ...
# 8            8       Principal Software Engineer - Data Migration
# 9            9                             Principal Statistician
# 10          10                               Programmer Analyst I
# 11          11            Salesforce Technical Architect - Remote
# 12          14         Staff Cybersecurity Data Platform Engineer
# ...

# %%
pd.read_csv("Listings/ZipRecruiter/"+remote)

# %%
pd.read_csv("Listings/Monster/"+remote)
# Out:
#      Unnamed: 0                                          job_title  \
# 0             0  (Remote) Business Analyst-Defense & Energy Glo...
# 1             1                                 .NET Data Engineer
# 2             2                   .NET Release Engineer--2nd Shift
# 3             3                                 .NET Web Developer
# 4             4                                  .Net/C# Developer
# ..          ...                                                ...
# 120         141  entry level data analyst / Data scientist/Pyth...
# 121         142  junior Java Developer/ software programmer/Dat...
# 122         143  junior Java software programmer/Data Analyst/D...
# 123         144  junior Java software programmer/Data Analyst/D...
# 124         145  junior software programmer/Data Analyst/Data S...
#
#                               company  \
# 0                     Vaco Technology
# 1                               Jobot
# 2                               Jobot
# ...
